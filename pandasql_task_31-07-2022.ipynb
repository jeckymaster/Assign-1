# %%
#Task 1 - Fitbit Dataset
# 1. Read this dataset in pandas , mysql and mongodb

# %%
import pandas as pd

# %%
fitbit_df = pd.read_csv("G:\\Backup 16-05-2022\\Downloads\\Data_set\\31-07-2022\\FitBit data.csv",index_col=False)

# %%
fitbit_df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
#3. convert all the dates avaible in dataset to timestamp format in pandas and in sql you to convert it in date format

# %%
fitbit_df['Conv_Activ_date'] = pd.to_datetime(fitbit_df['ActivityDate'])

# %%
fit = fitbit_df.head()

# %%
fit
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
#4 . Find out in this data that how many unique id's we have

# %%
unique_id = list(fitbit_df['Id'].unique())

# %%
len(unique_id)
# Out:
# 35

# %%
#5 . which id is one of the active id that you have in whole dataset

# %%
def convert_distance(a):
    return float(a)*100

# %%
conv_very_active_distance = []
for i in fitbit_df['VeryActiveDistance']:
    conv_very_active_distance.append(convert_distance(i))
conv_very_active_distance
fitbit_df['conv_very_active_distance']=conv_very_active_distance

# %%
fitbit_df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
fitbit_df.groupby(['Id'])['conv_very_active_distance'].sum()
# Out:
# Id
# 1503960366    5288.999981
# 1624580081      97.999999
# 1644430081    1133.999975
# 1844505072      61.000001
# 1927972279       0.000000
# 2022484408    3703.000028
# 2026352035       0.000000
# 2320127002      94.999998
# 2347167796    1291.999981
# 2873212765     395.999999
# 2891001357       0.000000
# 3372868164     743.999982
# 3977333714    1002.000011
# 4020332650     530.000003
# 4057192912     320.000006
# 4319703577     554.000002
# 4388161847       0.000000
# 4445114986     634.999996
# 4558609924     217.000002
# 4702921684     357.000004
# 5553957443    1814.000013
# 5577150313    3425.999975
# 6117666160      42.000000
# 6290855005     201.999998
# 6391747486     202.999997
# 6775888955     847.999985
# 6962181067    3613.000005
# 7007744171    4247.999926
# 7086361926    1834.999989
# 8053475328    9393.000007
# 8253242879     723.999983
# 8378563200    2358.000022
# 8583815059      37.000000
# 8792009665      57.999999
# 8877689391    8739.000034
# ...

# %%
fitbit_df.groupby(['Id'])['conv_very_active_distance'].sum().idxmax()
# Out:
# 8053475328

# %%
#6 . how many of them have not logged there activity find out in terms of number of ids

# %%
fitbit_df.groupby(['Id'])['LoggedActivitiesDistance'].sum().apply(lambda x : x<1).value_counts()
# Out:
# True     30
# False     5
# Name: LoggedActivitiesDistance, dtype: int64

# %%
#7 . Find out who is the laziest person id that we have in dataset

# %%
fitbit_df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
conv_light_active_distance = []
for i in fitbit_df['LightActiveDistance']:
    conv_light_active_distance.append(convert_distance(i))
conv_light_active_distance
fitbit_df['conv_light_active_distance']=conv_light_active_distance

# %%
fitbit_df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
fitbit_df.groupby(['Id'])['conv_light_active_distance'].sum()
# Out:
# Id
# 1503960366    7939.000022
# 1624580081    5052.999961
# 1644430081    3580.000019
# 1844505072    2788.999975
# 1927972279    1738.999994
# 2022484408    5766.999960
# 2026352035    2523.999977
# 2320127002    2397.999942
# 2347167796    6580.999947
# 2873212765    4651.999986
# 2891001357     483.000004
# 3372868164    3346.000028
# 3977333714    4306.999999
# 4020332650    7171.000036
# 4057192912    3317.000039
# 4319703577    4890.999961
# 4388161847       0.000000
# 4445114986    3660.999948
# 4558609924    4232.000047
# 4702921684    8084.000015
# 5553957443    3690.999985
# 5577150313    2952.000004
# 6117666160    5908.999991
# 6290855005     653.000021
# 6391747486     759.000003
# 6775888955    1640.999990
# 6962181067    5985.000011
# 7007744171    5589.000005
# 7086361926    2391.999994
# 8053475328    2795.000048
# 8253242879     950.999999
# 8378563200    4753.999996
# 8583815059    1788.000000
# 8792009665    2182.000023
# 8877689391    7527.000070
# ...

# %%
fitbit_df.groupby(['Id'])['conv_light_active_distance'].sum().idxmin()
# Out:
# 4388161847

# %%
#8 . Explore over an internet that how much calories burn is required for a healthy person and find out how many healthy person we have in our dataset

# %%
# According to internet the healthy person could burn at least 2200 calories in a day

# %%
fitbit_df.groupby(['Id'])['Calories'].max().apply(lambda x : x>2000).value_counts()
# Out:
# True     30
# False     5
# Name: Calories, dtype: int64

# %%
#9. how many person are not a regular person with respect to activity try to find out those

# %%
fitbit_df.groupby(['Id'])['TotalSteps'].apply(lambda x : x==0).value_counts()
# Out:
# False    396
# True      61
# Name: TotalSteps, dtype: int64

# %%
#10 . who is the thired most active person in this dataset find out those in pandas and in sql both .

# %%
fitbit_df.groupby(['Id'])['VeryActiveMinutes'].sum().sort_values(ascending =False)
# Out:
# Id
# 8053475328    933
# 5577150313    900
# 8877689391    802
# 1503960366    681
# 8378563200    665
# 7007744171    536
# 6962181067    495
# 2022484408    481
# 7086361926    315
# 5553957443    283
# 6775888955    179
# 2347167796    177
# 1644430081    148
# 3977333714    146
# 4020332650    130
# 3372868164    118
# 4319703577     79
# 6290855005     78
# 4445114986     76
# 8253242879     70
# 2873212765     61
# 4558609924     52
# 6391747486     46
# 4702921684     44
# 4057192912     40
# 8792009665     18
# 1624580081     14
# 2320127002     11
# 1844505072      9
# 6117666160      5
# 8583815059      5
# 4388161847      0
# 2891001357      0
# 2026352035      0
# 1927972279      0
# Name: VeryActiveMinutes, dtype: int64

# %%
fitbit_df.groupby(['Id'])['VeryActiveMinutes'].sum().sort_values(ascending =False)[2:3]
# Out:
# Id
# 8877689391    802
# Name: VeryActiveMinutes, dtype: int64

# %%
#11 . who is the 5th most laziest person avilable in dataset find it out

# %%
fitbit_df.groupby(['Id'])['LightlyActiveMinutes'].sum().sort_values()
# Out:
# Id
# 4388161847       0
# 6391747486     309
# 6290855005     393
# 8253242879     711
# 8583815059    1097
# 6775888955    1116
# 7086361926    1215
# 1927972279    1340
# 2891001357    1350
# 4057192912    1384
# 2320127002    1511
# 8792009665    1585
# 8053475328    1698
# 5577150313    1730
# 1844505072    1902
# 8378563200    2027
# 2026352035    2032
# 5553957443    2200
# 1644430081    2277
# 1624580081    2300
# 3977333714    2483
# 3372868164    2869
# 8877689391    2892
# 4319703577    2984
# 4558609924    2998
# 6117666160    2999
# 4445114986    3009
# 2022484408    3046
# 2873212765    3303
# 7007744171    3330
# 6962181067    3620
# 4702921684    3701
# 2347167796    3803
# 4020332650    4172
# 1503960366    4336
# Name: LightlyActiveMinutes, dtype: int64

# %%
fitbit_df.groupby(['Id'])['LightlyActiveMinutes'].sum().sort_values()[4:5]
# Out:
# Id
# 8583815059    1097
# Name: LightlyActiveMinutes, dtype: int64

# %%
#12 . what is a total acumulative calories burn for a person find out

# %%
fitbit_df.groupby(['Id'])['Calories'].sum()
# Out:
# Id
# 1503960366    34128
# 1624580081    25705
# 1644430081    29164
# 1844505072    19391
# 1927972279    27048
# 2022484408    29704
# 2026352035    16266
# 2320127002    18385
# 2347167796    30320
# 2873212765    20349
# 2891001357    18187
# 3372868164    18603
# 3977333714    16777
# 4020332650    98412
# 4057192912    60913
# 4319703577    23931
# 4388161847    14442
# 4445114986    31617
# 4558609924    21962
# 4702921684    42322
# 5553957443    21630
# 5577150313    36303
# 6117666160    20993
# 6290855005    21656
# 6391747486    15868
# 6775888955    24523
# 6962181067    29249
# 7007744171    31525
# 7086361926    26124
# 8053475328    31825
# 8253242879    17556
# 8378563200    40274
# 8583815059    19130
# 8792009665    24884
# 8877689391    41414
# Name: Calories, dtype: int64

# %%
st_usa_ord = pd.read_excel(r'G:\Backup 16-05-2022\Downloads\Data_set\31-07-2022\Superstore_USA.xlsx',sheet_name='Orders')

# %%
st_usa_ord
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
st_usa_retn = pd.read_excel(r'G:\Backup 16-05-2022\Downloads\Data_set\31-07-2022\Superstore_USA.xlsx',sheet_name='Returns')

# %%
st_usa_retn
# Out:
#       Order ID    Status
# 0           65  Returned
# 1          612  Returned
# 2          614  Returned
# 3          678  Returned
# 4          710  Returned
# ...        ...       ...
# 1629    182681  Returned
# 1630    182683  Returned
# 1631    182750  Returned
# 1632    182781  Returned
# 1633    182906  Returned
#
# [1634 rows x 2 columns]

# %%
st_usa_usr = pd.read_excel(r'G:\Backup 16-05-2022\Downloads\Data_set\31-07-2022\Superstore_USA.xlsx',sheet_name='Users')

# %%
st_usa_usr
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
#4 . try  to join order and return data both in sql and pandas

# %%
st_usa_fin = pd.merge(st_usa_ord,st_usa_retn)

# %%
st_usa_fin
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0     1359            Low      0.05        5.85           2.27           21
# 1     1950         Medium      0.01        4.91           0.50          117
# 2     1951         Medium      0.09        4.00           1.30          117
# 3     5055           High      0.02        3.28           5.00          117
# 4     5573            Low      0.02       11.97           5.81          272
# ..     ...            ...       ...         ...            ...          ...
# 93     986  Not Specified      0.06       37.94           5.08         3075
# 94     987  Not Specified      0.10       55.29           5.08         3075
# 95    6041         Medium      0.05        4.28           6.18         3075
# 96    1910           High      0.05       14.48           1.99         3079
# 97    6625           High      0.06      128.24          12.65         3251
#
# ...

# %%
#3 . Find out how return that we ahve recived and with a product id

# %%
st_usa_fin.groupby(['Row ID'])['Status'].count()
# Out:
# Row ID
# 95      1
# 96      1
# 653     1
# 654     1
# 979     1
#        ..
# 8079    1
# 8080    1
# 8081    1
# 8251    1
# 8389    1
# Name: Status, Length: 98, dtype: int64

# %%
#5 . Try to find out how many unique customer that we have

# %%
len(st_usa_ord['Customer ID'].unique())
# Out:
# 2703

# %%
#6 . try to find out in how many regions we are selling a product and who is a manager for a respective region

# %%
st_usa_ord.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %%
st_usa_ord['Region'].unique()
# Out:
# array(['Central', 'West', 'East', 'South'], dtype=object)

# %%
st_usa_usr
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
#7 . find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset

# %%
shipm = st_usa_ord['Ship Mode']

# %%
shipm
# Out:
# 0          Regular Air
# 1          Express Air
# 2          Express Air
# 3          Regular Air
# 4          Express Air
#              ...
# 9421       Regular Air
# 9422       Regular Air
# 9423    Delivery Truck
# 9424       Express Air
# 9425       Express Air
# Name: Ship Mode, Length: 9426, dtype: object

# %%
ship_count = pd.Series(shipm).value_counts()
ship_count
# Out:
# Regular Air       7036
# Delivery Truck    1283
# Express Air       1107
# Name: Ship Mode, dtype: int64

# %%
ship_1 = pd.DataFrame(ship_count)
ship_1
# Out:
#                 Ship Mode
# Regular Air          7036
# Delivery Truck       1283
# Express Air          1107

# %%
shipment_total = ship_1.sum()
shipment_total
# Out:
# Ship Mode    9426
# dtype: int64

# %%
((ship_1[['Ship Mode']])/shipment_total)*100 #percentage
# Out:
#                 Ship Mode
# Regular Air     74.644600
# Delivery Truck  13.611288
# Express Air     11.744112

# %%
#8 . Create a new coulmn and try to find our a diffrence between order date and shipment date

# %%
st_usa_ord["difference_date"] =  st_usa_ord['Ship Date'] - st_usa_ord['Order Date'] 
st_usa_ord
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
#9 . base on question number 8 find out for which order id we have shipment duration more than 10 days

# %%
st_usa_ord[(st_usa_ord['difference_date'].dt.components['days']>10)]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 643    18246       Critical      0.05       11.09           5.25          250
# 1548   23091         Medium      0.04      100.98           7.18          595
# 1549   23092         Medium      0.09        6.48           7.49          595
# 1678   20703  Not Specified      0.07      130.98          30.00          637
# 1679   20704  Not Specified      0.09       55.98           4.86          637
# 1680   20705  Not Specified      0.08      115.99           4.23          637
# 1697    2703  Not Specified      0.07      130.98          30.00          640
# 1698    2704  Not Specified      0.09       55.98           4.86          640
# 1699    2705  Not Specified      0.08      115.99           4.23          640
# 2515   18060            Low      0.02        2.21           1.00          964
# 5548   21603  Not Specified      0.02        5.58           1.99         2048
# ...

# %%
#10 . Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well

# %%
st_usa_fin.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0    1359            Low      0.05        5.85           2.27           21
# 1    1950         Medium      0.01        4.91           0.50          117
# 2    1951         Medium      0.09        4.00           1.30          117
# 3    5055           High      0.02        3.28           5.00          117
# 4    5573            Low      0.02       11.97           5.81          272
#
#           Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Tony Wilkins Winters  Regular Air   Small Business  Office Supplies  ...
# 1           Linda Weiss  Regular Air      Home Office  Office Supplies  ...
# 2           Linda Weiss  Express Air      Home Office  Office Supplies  ...
# 3           Linda Weiss  Regular Air      Home Office  Office Supplies  ...
# 4         Eleanor Swain  Regular Air   Small Business  Office Supplies  ...
#
# ...

# %%
st_usa_fin["difference_date"] =  st_usa_fin['Ship Date'] - st_usa_fin['Order Date'] 
st_usa_fin
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0     1359            Low      0.05        5.85           2.27           21
# 1     1950         Medium      0.01        4.91           0.50          117
# 2     1951         Medium      0.09        4.00           1.30          117
# 3     5055           High      0.02        3.28           5.00          117
# 4     5573            Low      0.02       11.97           5.81          272
# ..     ...            ...       ...         ...            ...          ...
# 93     986  Not Specified      0.06       37.94           5.08         3075
# 94     987  Not Specified      0.10       55.29           5.08         3075
# 95    6041         Medium      0.05        4.28           6.18         3075
# 96    1910           High      0.05       14.48           1.99         3079
# 97    6625           High      0.06      128.24          12.65         3251
#
# ...

# %%
st_usa_fin[(st_usa_fin['difference_date'].dt.components['days']>15)]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order Priority, Discount, Unit Price, Shipping Cost, Customer ID, Customer Name, Ship Mode, Customer Segment, Product Category, Product Sub-Category, Product Container, Product Name, Product Base Margin, Region, State or Province, City, Postal Code, Order Date, Ship Date, Profit, Quantity ordered new, Sales, Order ID, Status, difference_date]
# Index: []
#
# [0 rows x 26 columns]

# %%
#11 . Gorup by region and find out which region is more profitable

# %%
st_usa_ord.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'difference_date'],
#       dtype='object')

# %%
st_usa_ord.groupby(['Region'])['Profit'].max()
# Out:
# Region
# Central    12504.9045
# East        9228.2256
# South      16332.4140
# West        8917.7187
# Name: Profit, dtype: float64

# %%
#12 . Try to find out overalll in which country we are giving more discount

# %%
st_usa_ord.groupby(['State or Province'])['Discount'].max().sort_values(ascending =False)
# Out:
# State or Province
# Illinois                0.25
# Minnesota               0.17
# Alabama                 0.10
# Rhode Island            0.10
# New Jersey              0.10
# New Mexico              0.10
# New York                0.10
# North Carolina          0.10
# North Dakota            0.10
# Ohio                    0.10
# Oklahoma                0.10
# Oregon                  0.10
# Pennsylvania            0.10
# South Carolina          0.10
# Nevada                  0.10
# South Dakota            0.10
# Tennessee               0.10
# Texas                   0.10
# Utah                    0.10
# Vermont                 0.10
# Virginia                0.10
# Washington              0.10
# West Virginia           0.10
# Wisconsin               0.10
# New Hampshire           0.10
# Montana                 0.10
# Nebraska                0.10
# Arizona                 0.10
# Arkansas                0.10
# California              0.10
# Colorado                0.10
# ...

# %%
st_usa_ord.groupby(['State or Province'])['Discount'].max().sort_values(ascending =False)[0:1]
# Out:
# State or Province
# Illinois    0.25
# Name: Discount, dtype: float64

# %%
#13 . Give me a list of unique postal code

# %%
list(st_usa_ord['Postal Code'].unique())
# Out:
# [60101,
#  98221,
#  91776,
#  95123,
#  2724,
#  3110,
#  8101,
#  8109,
#  7203,
#  2907,
#  55372,
#  11787,
#  13210,
#  59405,
#  59601,
#  59801,
#  68005,
#  10012,
#  92653,
#  92677,
#  92530,
#  92630,
#  90712,
#  93534,
#  90260,
#  97405,
#  97526,
#  97030,
#  97123,
#  97303,
#  62002,
#  98373,
#  98052,
#  75019,
#  23834,
#  62701,
#  60107,
#  60477,
#  14150,
#  12180,
#  77642,
#  75080,
#  77471,
#  78664,
#  75088,
#  24153,
#  94043,
#  92563,
#  94559,
#  10177,
#  2917,
#  5401,
#  4070,
#  2331,
#  8830,
#  8701,
#  7470,
#  7481,
#  5201,
#  97035,
#  44708,
#  45231,
#  44105,
#  95687,
#  5451,
#  94591,
#  70056,
#  22102,
#  60601,
#  66209,
#  66215,
#  66502,
#  66062,
#  6510,
#  4401,
#  4005,
#  2129,
#  2038,
#  1852,
#  1752,
#  2067,
#  3820,
#  8618,
#  7644,
#  7110,
#  8861,
#  7095,
#  2895,
#  97128,
#  97504,
#  98103,
#  84118,
#  84041,
#  93277,
#  76903,
#  78207,
#  60004,
#  94952,
#  1510,
#  1106,
#  1880,
#  6401,
#  6360,
# ...

# %%
st_usa_ord.head(20)
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0    18606  Not Specified      0.01        2.88           0.50            2
# 1    20847           High      0.01        2.84           0.93            3
# 2    23086  Not Specified      0.03        6.68           6.15            3
# 3    23087  Not Specified      0.01        5.68           3.60            3
# 4    23088  Not Specified      0.00      205.99           2.50            3
# 5    23597         Medium      0.09       55.48          14.30            3
# 6    25549            Low      0.08      120.97          26.30            3
# 7    20228  Not Specified      0.02      500.98          26.00            5
# 8    19483            Low      0.08        6.48           6.81            5
# 9    24782           High      0.01       90.24           0.99            6
# 10   24563       Critical      0.07        6.48           6.60            6
# ...

# %%
  #  14 . which customer segement is more profitalble find it out

# %%
st_usa_ord.groupby(['Customer Segment'])['Profit'].max()
# Out:
# Customer Segment
# Consumer           8118.8919
# Corporate         12504.9045
# Home Office       16332.4140
# Small Business    11429.4774
# Name: Profit, dtype: float64

# %%
st_usa_ord.groupby(['Customer Segment'])['Profit'].max().sort_values(ascending =False)[0:1]
# Out:
# Customer Segment
# Home Office    16332.414
# Name: Profit, dtype: float64

# %%
# 15 . try to find out the 10th most loss making product catagory .

# %%
st_usa_ord.groupby(['Product Category'])['Profit'].min()
# Out:
# Product Category
# Furniture         -13706.46400
# Office Supplies   -14369.12358
# Technology        -16476.83800
# Name: Profit, dtype: float64

# %%
st_usa_ord[st_usa_ord['Profit']<0].reset_index().sort_values('Profit', ascending = True).head(10)
# Out:
#       index  Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 2291   4659   18306         Medium      0.08      175.99           4.99
# 2121   4338   20972            Low      0.01       24.95           2.99
# 3811   7800   23213            Low      0.09     6783.02          24.49
# 2381   4844   21284       Critical      0.04      880.98          44.55
# 2660   5402   24076         Medium      0.04     6783.02          24.49
# 2664   5409   22942           High      0.05     3502.14           8.73
# 3771   7725   21048  Not Specified      0.06     6783.02          24.49
# 1061   2191   21575  Not Specified      0.05     3499.99          24.49
# 1977   4068   21917           High      0.06     3502.14           8.73
# 2387   4857   24251           High      0.05     3502.14           8.73
#
#       Customer ID         Customer Name       Ship Mode Customer Segment  ...  \
# 2291         1738          Dean Solomon     Regular Air        Corporate  ...
# ...

# %%
st_usa_ord[st_usa_ord['Profit']<0].reset_index().sort_values('Profit', ascending = True).iloc[[9]]
# Out:
#       index  Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 2387   4857   24251           High      0.05     3502.14           8.73
#
#       Customer ID   Customer Name       Ship Mode Customer Segment  ...  \
# 2387         1796  Carlos Johnson  Delivery Truck        Corporate  ...
#
#      State or Province           City Postal Code Order Date  Ship Date  \
# 2387        California  San Francisco       94110 2013-03-23 2013-03-24
#
#          Profit Quantity ordered new   Sales  Order ID difference_date
# 2387 -7961.4309                    1  3360.3     90778          1 days
#
# [1 rows x 26 columns]

# %%
st_usa_ord.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'difference_date'],
#       dtype='object')

# %%
#6 . Try to find out 10 top  product with highest margins

# %%
st_usa_ord.sort_values(['Product Base Margin'])['Product Name'].head(10)
# Out:
# 2431              GBC DocuBind 200 Manual Binding Machine
# 8248       Peel & Seel® Recycled Catalog Envelopes, Brown
# 1515       Peel & Seel® Recycled Catalog Envelopes, Brown
# 5050       Peel & Seel® Recycled Catalog Envelopes, Brown
# 413                                           Accessory31
# 5034                          Prang Dustless Chalk Sticks
# 8308         Staples Brown Kraft Recycled Clasp Envelopes
# 8311     Storex DuraTech Recycled Plastic Frosted Binders
# 8318                                          Accessory31
# 1553    Adams Telephone Message Book w/Frequently-Call...
# Name: Product Name, dtype: object
