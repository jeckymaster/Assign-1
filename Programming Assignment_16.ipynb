# %% [markdown]
# Question1.
#
# Write a function that stutters a word as if someone is struggling to read it. The first two letters are repeated twice with an ellipsis ... and space after each, and then the word is pronounced with a question mark ?.
#
# Examples
#
# stutter("incredible") ➞ "in... in... incredible?"
#
# stutter("enthusiastic") ➞ "en... en... enthusiastic?"
#
# stutter("outstanding") ➞ "ou... ou... outstanding?"
#
# Hint :- Assume all input is in lower case and at least two characters long.

# %%
def stutter(word):
    first_two_letters = word[:2]
    return f"{first_two_letters}... {first_two_letters}... {word}?"

# %%
word = input("Enter the word :")
stutter(word)
# Out:
# Enter the word :incredible
# 'in... in... incredible?'

# %% [markdown]
# Question 2.
# Create a function that takes an angle in radians and returns the corresponding angle in degrees rounded to one decimal place.
#
# Examples
#
# radians_to_degrees(1) ➞ 57.3
#
# radians_to_degrees(20) ➞ 1145.9
#
# radians_to_degrees(50) ➞ 2864.8

# %%
import math

def radians_to_degrees(radian):
    degree = round(radian * 180 / math.pi,1)
    return degree

# %%
radian = int(input("Enter the radian to convert into degree :"))
converted_degree = radians_to_degrees(radian)
print(f"radians_to_degrees({radian}) => {converted_degree}")
# Out:
# Enter the radian to convert into degree :20
# radians_to_degrees(20) => 1145.9

# %% [markdown]
# Question 3.
# In this challenge, establish if a given integer num is a Curzon number. If 1 plus 2 elevated to num is exactly divisible by 1 plus 2 multiplied by num, then num is a Curzon number.
#
# Given a non-negative integer num, implement a function that returns True if num is a Curzon number, or False otherwise.
#
# Examples
#
# is_curzon(5) ➞ True
# - 2 ** 5 + 1 = 33
# - 2 * 5 + 1 = 11
# - 33 is a multiple of 11
#
# is_curzon(10) ➞ False
# - 2 ** 10 + 1 = 1025
# - 2 * 10 + 1 = 21
# - 1025 is not a multiple of 21
#
# is_curzon(14) ➞ True
# - 2 ** 14 + 1 = 16385
# - 2 * 14 + 1 = 29
# - 16385 is a multiple of 29

# %%
def is_num_corzon(num):
    sum1 = 2**num + 1
    sum2 = 2*num +1
    if sum1 % sum2 == 0:
        print(f"is_curzon ({num}) => True")
    else:
        print(f"is_curzon ({num}) => False")

# %%
num = int(input("Enter the number to find is_curzon:"))
is_num_corzon(num)
# Out:
# Enter the number to find is_curzon:10
# is_curzon (10) => False

# %% [markdown]
# Question 4.
# Given the side length x find the area of a hexagon.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Examples
#
# area_of_hexagon(1) ➞ 2.6
#
# area_of_hexagon(2) ➞ 10.4
#
# area_of_hexagon(3) ➞ 23.4

# %%
import math

def sqrt(x):
    return math.sqrt(x)

def area_hexagon(side):
    
    area = round(3 *sqrt(3) * side **2 /2, 1)
    return print(f"area_of_hexagon({side}) => {area}")

# %%
side = int(input("Enter the length of side of Regular Hexagon :"))
area_hex = area_hexagon(side)
# Out:
# Enter the length of side of Regular Hexagon :2
# area_of_hexagon(2) => 10.4

# %% [markdown]
# Question 5.
#
# Create a function that returns a base-2 (binary) representation of a base-10 (decimal) string number. To convert is simple: ((2) means base-2 and (10) means base-10) 010101001(2) = 1 + 8 + 32 + 128.
#
# Going from right to left, the value of the most right bit is 1, now from that every bit to the left will be x2 the value, value of an 8 bit binary numbers are (256, 128, 64, 32, 16, 8, 4, 2, 1).
#
# Examples
#
# binary(1) ➞ "1"
# - 1*1 = 1
#
# binary(5) ➞ "101"
# - 1*1 + 1*4 = 5
#
# binary(10) ➞ "1010"
# - 1*2 + 1*8 = 10

# %%
def binary(deci):
    if deci == 0:
        return "0"
    
    binary_num = ""
    while deci > 0:
        binary_num = str(deci % 2) + binary_num
        deci //= 2
        
    return binary_num

# %%
deci = int(input("Enter the decimal number:"))
cov_binary = binary(deci)
print(f"binary({deci}) => {cov_binary}")
# Out:
# Enter the decimal number:10
# binary(10) => 1010
